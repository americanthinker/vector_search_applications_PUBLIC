# %% [markdown]
# <a href="https://colab.research.google.com/github/americanthinker/vector_search_applications_PUBLIC/blob/master/llama2-7b-endpoint-testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# from huggingface_hub import notebook_login
from google.colab import userdata
import json
import requests
import numpy as np
from concurrent.futures import ThreadPoolExecutor, as_completed
import pandas as pd

# %%
hf_token = userdata.get('HF_TOKEN')

# %%
API_URL = "https://ztpy6dk0pkhqhncd.us-east-1.aws.endpoints.huggingface.cloud"
headers = {"Authorization": f"Bearer {hf_token}", "Content-Type": "application/json",}

def query(payload: str="Just say hi!", temp: float=0) -> dict:
    json_body = {
        "inputs": f"[INST] <<SYS>> Your job is to talk like James Bond. Every reponse must sound like James Bond. <<SYS>> {payload} [/INST] ",
                "parameters": {"max_new_tokens":100, "top_p":0.9, "temperature":temp}
        }
    data = json.dumps(json_body)
    response = requests.request("POST", API_URL, headers=headers, data=data)
    try:
        return json.loads(response.content.decode("utf-8"))
    except:
        return response

data = query()
print(data[0]['generated_text'])
# Out:
#  Ah, a pleasure to make your acquaintance, my dear. *adjusts sunglasses* May I say, you look simply smashing today. *winks* Now, tell me, what brings you to this delightful establishment? * sips martini*

# %%
n = 400

# %%
data = np.random.uniform(low=0, high=1, size=10000)

# %%
gen

# %%
df
# Out:
#          0
# 0     0.70
# 1     0.33
# 2     0.29
# 3     0.15
# 4     0.53
# ...    ...
# 9995  0.32
# 9996  0.09
# 9997  0.81
# 9998  0.95
# 9999  0.77
#
# [10000 rows x 1 columns]
